# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/keras-team/autokeras/blob/master/docs/templates/tutorial/image_classification.ipynb)

# %%
pip install autokeras

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# ### Create synthetic image - tags dataset

# %%
import numpy as np

num_instances = 100

# Generate image data.
image_data = np.random.rand(num_instances, 32, 32, 3).astype(np.float32)
image_train, image_test = image_data[:80], image_data[80:]

# Generate structured data.
structured_data = np.random.rand(num_instances, 20).astype(np.float32)
structured_train, structured_test = structured_data[:80], structured_data[80:]

# Generate classification labels of five classes.
classification_target = np.random.randint(5, size=num_instances)
target_train, target_test = classification_target[:80], classification_target[80:]

# %% [markdown]
# ### IO API for image classification

# %%
import autokeras as ak

# Initialize the IO API.
multi_modal_clf = ak.AutoModel(
    inputs=[ak.ImageInput(), ak.StructuredDataInput()],
    outputs=ak.ClassificationHead(),
    max_trials=3
)

# Fit the model with prepared data.
multi_modal_clf.fit(
    [image_train, structured_train],
    target_train,
    epochs=10, 
    verbose=2
)
# Out:
# Train for 2 steps, validate for 1 steps
# Epoch 1/10
# 2/2 - 3s - loss: 1.6180 - accuracy: 0.2031 - val_loss: 1.6585 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 2/2 - 0s - loss: 1.5630 - accuracy: 0.2812 - val_loss: 1.7249 - val_accuracy: 0.0000e+00
# Epoch 3/10
# 2/2 - 0s - loss: 1.5588 - accuracy: 0.2812 - val_loss: 1.6548 - val_accuracy: 0.0000e+00
# Epoch 4/10
# 2/2 - 0s - loss: 1.5407 - accuracy: 0.2812 - val_loss: 1.6071 - val_accuracy: 0.0000e+00
# Epoch 5/10
# 2/2 - 0s - loss: 1.5292 - accuracy: 0.2969 - val_loss: 1.6163 - val_accuracy: 0.0000e+00
# Epoch 6/10
# 2/2 - 0s - loss: 1.5178 - accuracy: 0.2969 - val_loss: 1.6373 - val_accuracy: 0.0000e+00
# Epoch 7/10
# 2/2 - 0s - loss: 1.5028 - accuracy: 0.2812 - val_loss: 1.6526 - val_accuracy: 0.0000e+00
# Epoch 8/10
# 2/2 - 0s - loss: 1.4874 - accuracy: 0.2812 - val_loss: 1.6543 - val_accuracy: 0.0000e+00
# Epoch 9/10
# 2/2 - 0s - loss: 1.4724 - accuracy: 0.2812 - val_loss: 1.6488 - val_accuracy: 0.0000e+00
# Epoch 10/10
# ...

# %% [markdown]
# ### Retrieve best model

# %%
best_model = multi_modal_clf.export_model()
best_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 16, 16, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 18, 18, 64)   0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 8, 8, 64)     0           pool1_pad[0][0]
# ...

# %%
tf.keras.utils.plot_model(best_model, show_shapes=True, expand_nested=True)

# %% [markdown]
# ### Predict with the best model.

# %%
structured_test.shape
# Out:
# (20, 20)

# %%
predicted_y = multi_modal_clf.predict([image_test, structured_test])
print(predicted_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-8c6d0a83f728> in <module>
# ----> 1 predicted_y = multi_modal_clf.predict([image_test, structured_test])
#       2 print(predicted_y)
#
# ~/.virtualenvs/book/lib/python3.6/site-packages/autokeras/auto_model.py in predict(self, x, batch_size, **kwargs)
#     339             dataset = self._process_x(x, False)
#     340         dataset = dataset.batch(batch_size)
# --> 341         model = self.tuner.get_best_model()
#     342         y = model.predict(dataset, **kwargs)
#     343         y = self._postprocess(y)
#
# ~/.virtualenvs/book/lib/python3.6/site-packages/autokeras/engine/tuner.py in get_best_model(self)
#      40
#      41     def get_best_model(self):
# ---> 42         model = super().get_best_models()[0]
#      43         model.load_weights(self.best_model_path)
#      44         return model
#
# ...

# %% [markdown]
# ### Evaluate the best model on the test data.

# %%
test_loss, test_acc = multi_modal_clf.evaluate([image_test, structured_test], target_test, verbose=0)
print('Test accuracy: ', test_acc)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# ...

# %% [markdown]
# ## Reference
# [ImageClassifier](/image_classifier),
# [AutoModel](/auto_model/#automodel-class),
# [ImageBlock](/block/#imageblock-class),
# [Normalization](/preprocessor/#normalization-class),
# [ImageAugmentation](/preprocessor/#image-augmentation-class),
# [ResNetBlock](/block/#resnetblock-class),
# [ImageInput](/node/#imageinput-class),
# [ClassificationHead](/head/#classificationhead-class).
