# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/keras-team/autokeras/blob/master/docs/templates/tutorial/image_classification.ipynb)

# %%
import tensorflow as tf
import autokeras as ak
tf.__version__
# Out:
# '2.3.1'

# %% [markdown]
# ### Load California housing price prediction dataset

# %%
from sklearn.datasets import fetch_california_housing

house_dataset = fetch_california_housing()

# Import pandas package to format the data
import pandas as pd

# Extract features with their names into the a dataframe format
data = pd.DataFrame(house_dataset.data, columns=house_dataset.feature_names)

# Extract target with their names into a pd.Series object with name MEDV
target = pd.Series(house_dataset.target, name = 'MEDV')

from sklearn.model_selection import train_test_split
train_data, test_data, train_targets, test_targets = train_test_split(data, target, test_size=0.2, random_state=42)

# %%
# Check the shape of whole dataset and the splited training and test set
print("--Shape of the whole data--\n {}".format(data.shape))
print("\n--Shape of the target vector--\n {}".format(target.shape))
print("\n--Shape of the training data--\n {}".format(train_data.shape))
print("\n--Shape of the testing data--\n {}".format(test_data.shape))
# Out:
# --Shape of the whole data--
#  (20640, 8)
#
# --Shape of the target vector--
#  (20640,)
#
# --Shape of the training data--
#  (16512, 8)
#
# --Shape of the testing data--
#  (4128, 8)

# %% [markdown]
# ### Run the StructuredDataRegressor

# %%
regressor = ak.StructuredDataRegressor(max_trials=10)

regressor.fit(x=train_data, y=train_targets, batch_size=1024, verbose=2)
# Out:
# Trial 10 Complete [00h 00m 18s]
# val_loss: 0.8176659941673279
#
# Best val_loss So Far: 0.31725212931632996
# Total elapsed time: 00h 11m 16s
# INFO:tensorflow:Oracle triggered exit
# WARNING:tensorflow:Layer multi_category_encoding is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# Epoch 1/237
# 17/17 - 0s - loss: 4.6831 - mean_squared_error: 4.6831
# Epoch 2/237
# 17/17 - 0s - loss: 2.6251 - mean_squared_error: 2.6251
# Epoch 3/237
# 17/17 - 0s - loss: 1.4841 - mean_squared_error: 1.4841
# Epoch 4/237
# 17/17 - 0s - loss: 0.9361 - mean_squared_error: 0.9361
# Epoch 5/237
# 17/17 - 0s - loss: 0.7683 - mean_squared_error: 0.7683
# Epoch 6/237
# 17/17 - 0s - loss: 0.7026 - mean_squared_error: 0.7026
# Epoch 7/237
# 17/17 - 0s - loss: 0.6563 - mean_squared_error: 0.6563
# Epoch 8/237
# 17/17 - 0s - loss: 0.6165 - mean_squared_error: 0.6165
# Epoch 9/237
# 17/17 - 0s - loss: 0.5815 - mean_squared_error: 0.5815
# Epoch 10/237
# 17/17 - 0s - loss: 0.5514 - mean_squared_error: 0.5514
# Epoch 11/237
# 17/17 - 0s - loss: 0.5257 - mean_squared_error: 0.5257
# Epoch 12/237
# 17/17 - 0s - loss: 0.5041 - mean_squared_error: 0.5041
# Epoch 13/237
# 17/17 - 0s - loss: 0.4859 - mean_squared_error: 0.4859
# Epoch 14/237
# 17/17 - 0s - loss: 0.4706 - mean_squared_error: 0.4706
# Epoch 15/237
# 17/17 - 0s - loss: 0.4574 - mean_squared_error: 0.4574
# Epoch 16/237
# 17/17 - 0s - loss: 0.4461 - mean_squared_error: 0.4461
# Epoch 17/237
# 17/17 - 0s - loss: 0.4369 - mean_squared_error: 0.4369
# Epoch 18/237
# 17/17 - 0s - loss: 0.4295 - mean_squared_error: 0.4295
# Epoch 19/237
# 17/17 - 0s - loss: 0.4232 - mean_squared_error: 0.4232
# Epoch 20/237
# 17/17 - 0s - loss: 0.4177 - mean_squared_error: 0.4177
# Epoch 21/237
# 17/17 - 0s - loss: 0.4130 - mean_squared_error: 0.4130
# Epoch 22/237
# 17/17 - 0s - loss: 0.4089 - mean_squared_error: 0.4089
# Epoch 23/237
# 17/17 - 0s - loss: 0.4051 - mean_squared_error: 0.4051
# Epoch 24/237
# 17/17 - 0s - loss: 0.4016 - mean_squared_error: 0.4016
# Epoch 25/237
# 17/17 - 0s - loss: 0.3982 - mean_squared_error: 0.3982
# Epoch 26/237
# 17/17 - 0s - loss: 0.3950 - mean_squared_error: 0.3950
# Epoch 27/237
# 17/17 - 0s - loss: 0.3919 - mean_squared_error: 0.3919
# Epoch 28/237
# 17/17 - 0s - loss: 0.3889 - mean_squared_error: 0.3889
# Epoch 29/237
# 17/17 - 0s - loss: 0.3860 - mean_squared_error: 0.3860
# Epoch 30/237
# 17/17 - 0s - loss: 0.3831 - mean_squared_error: 0.3831
# Epoch 31/237
# 17/17 - 0s - loss: 0.3803 - mean_squared_error: 0.3803
# Epoch 32/237
# 17/17 - 0s - loss: 0.3777 - mean_squared_error: 0.3777
# Epoch 33/237
# 17/17 - 0s - loss: 0.3749 - mean_squared_error: 0.3749
# Epoch 34/237
# 17/17 - 0s - loss: 0.3726 - mean_squared_error: 0.3726
# Epoch 35/237
# 17/17 - 0s - loss: 0.3700 - mean_squared_error: 0.3700
# Epoch 36/237
# 17/17 - 0s - loss: 0.3677 - mean_squared_error: 0.3677
# Epoch 37/237
# 17/17 - 0s - loss: 0.3652 - mean_squared_error: 0.3652
# Epoch 38/237
# 17/17 - 0s - loss: 0.3630 - mean_squared_error: 0.3630
# Epoch 39/237
# 17/17 - 0s - loss: 0.3605 - mean_squared_error: 0.3605
# Epoch 40/237
# 17/17 - 0s - loss: 0.3582 - mean_squared_error: 0.3582
# Epoch 41/237
# 17/17 - 0s - loss: 0.3558 - mean_squared_error: 0.3558
# Epoch 42/237
# 17/17 - 0s - loss: 0.3537 - mean_squared_error: 0.3537
# Epoch 43/237
# 17/17 - 0s - loss: 0.3514 - mean_squared_error: 0.3514
# Epoch 44/237
# 17/17 - 0s - loss: 0.3496 - mean_squared_error: 0.3496
# Epoch 45/237
# 17/17 - 0s - loss: 0.3475 - mean_squared_error: 0.3475
# Epoch 46/237
# 17/17 - 0s - loss: 0.3458 - mean_squared_error: 0.3458
# Epoch 47/237
# 17/17 - 0s - loss: 0.3437 - mean_squared_error: 0.3437
# Epoch 48/237
# 17/17 - 0s - loss: 0.3421 - mean_squared_error: 0.3421
# Epoch 49/237
# 17/17 - 0s - loss: 0.3402 - mean_squared_error: 0.3402
# Epoch 50/237
# 17/17 - 0s - loss: 0.3387 - mean_squared_error: 0.3387
# Epoch 51/237
# 17/17 - 0s - loss: 0.3368 - mean_squared_error: 0.3368
# Epoch 52/237
# 17/17 - 0s - loss: 0.3356 - mean_squared_error: 0.3356
# Epoch 53/237
# 17/17 - 0s - loss: 0.3339 - mean_squared_error: 0.3339
# Epoch 54/237
# 17/17 - 0s - loss: 0.3330 - mean_squared_error: 0.3330
# Epoch 55/237
# 17/17 - 0s - loss: 0.3311 - mean_squared_error: 0.3311
# Epoch 56/237
# 17/17 - 0s - loss: 0.3304 - mean_squared_error: 0.3304
# Epoch 57/237
# 17/17 - 0s - loss: 0.3286 - mean_squared_error: 0.3286
# Epoch 58/237
# 17/17 - 0s - loss: 0.3282 - mean_squared_error: 0.3282
# Epoch 59/237
# 17/17 - 0s - loss: 0.3263 - mean_squared_error: 0.3263
# Epoch 60/237
# 17/17 - 0s - loss: 0.3256 - mean_squared_error: 0.3256
# Epoch 61/237
# 17/17 - 0s - loss: 0.3237 - mean_squared_error: 0.3237
# Epoch 62/237
# 17/17 - 0s - loss: 0.3232 - mean_squared_error: 0.3232
# Epoch 63/237
# 17/17 - 0s - loss: 0.3218 - mean_squared_error: 0.3218
# Epoch 64/237
# 17/17 - 0s - loss: 0.3211 - mean_squared_error: 0.3211
# Epoch 65/237
# 17/17 - 0s - loss: 0.3196 - mean_squared_error: 0.3196
# Epoch 66/237
# 17/17 - 0s - loss: 0.3190 - mean_squared_error: 0.3190
# Epoch 67/237
# 17/17 - 0s - loss: 0.3178 - mean_squared_error: 0.3178
# Epoch 68/237
# 17/17 - 0s - loss: 0.3171 - mean_squared_error: 0.3171
# Epoch 69/237
# 17/17 - 0s - loss: 0.3159 - mean_squared_error: 0.3159
# Epoch 70/237
# 17/17 - 0s - loss: 0.3153 - mean_squared_error: 0.3153
# Epoch 71/237
# 17/17 - 0s - loss: 0.3142 - mean_squared_error: 0.3142
# Epoch 72/237
# 17/17 - 0s - loss: 0.3136 - mean_squared_error: 0.3136
# Epoch 73/237
# 17/17 - 0s - loss: 0.3125 - mean_squared_error: 0.3125
# Epoch 74/237
# 17/17 - 0s - loss: 0.3121 - mean_squared_error: 0.3121
# Epoch 75/237
# 17/17 - 0s - loss: 0.3110 - mean_squared_error: 0.3110
# Epoch 76/237
# 17/17 - 0s - loss: 0.3106 - mean_squared_error: 0.3106
# Epoch 77/237
# 17/17 - 0s - loss: 0.3095 - mean_squared_error: 0.3095
# Epoch 78/237
# 17/17 - 0s - loss: 0.3093 - mean_squared_error: 0.3093
# Epoch 79/237
# 17/17 - 0s - loss: 0.3082 - mean_squared_error: 0.3082
# Epoch 80/237
# 17/17 - 0s - loss: 0.3078 - mean_squared_error: 0.3078
# Epoch 81/237
# 17/17 - 0s - loss: 0.3069 - mean_squared_error: 0.3069
# Epoch 82/237
# 17/17 - 0s - loss: 0.3072 - mean_squared_error: 0.3072
# Epoch 83/237
# 17/17 - 0s - loss: 0.3063 - mean_squared_error: 0.3063
# Epoch 84/237
# 17/17 - 0s - loss: 0.3065 - mean_squared_error: 0.3065
# Epoch 85/237
# 17/17 - 0s - loss: 0.3054 - mean_squared_error: 0.3054
# Epoch 86/237
# 17/17 - 0s - loss: 0.3051 - mean_squared_error: 0.3051
# Epoch 87/237
# 17/17 - 0s - loss: 0.3038 - mean_squared_error: 0.3038
# Epoch 88/237
# 17/17 - 0s - loss: 0.3034 - mean_squared_error: 0.3034
# Epoch 89/237
# 17/17 - 0s - loss: 0.3028 - mean_squared_error: 0.3028
# Epoch 90/237
# 17/17 - 0s - loss: 0.3024 - mean_squared_error: 0.3024
# Epoch 91/237
# 17/17 - 0s - loss: 0.3016 - mean_squared_error: 0.3016
# Epoch 92/237
# 17/17 - 0s - loss: 0.3013 - mean_squared_error: 0.3013
# Epoch 93/237
# 17/17 - 0s - loss: 0.3008 - mean_squared_error: 0.3008
# Epoch 94/237
# 17/17 - 0s - loss: 0.3003 - mean_squared_error: 0.3003
# Epoch 95/237
# 17/17 - 0s - loss: 0.2997 - mean_squared_error: 0.2997
# Epoch 96/237
# 17/17 - 0s - loss: 0.2994 - mean_squared_error: 0.2994
# Epoch 97/237
# 17/17 - 0s - loss: 0.2989 - mean_squared_error: 0.2989
# Epoch 98/237
# 17/17 - 0s - loss: 0.2986 - mean_squared_error: 0.2986
# Epoch 99/237
# 17/17 - 0s - loss: 0.2980 - mean_squared_error: 0.2980
# Epoch 100/237
# 17/17 - 0s - loss: 0.2977 - mean_squared_error: 0.2977
# Epoch 101/237
# 17/17 - 0s - loss: 0.2971 - mean_squared_error: 0.2971
# Epoch 102/237
# 17/17 - 0s - loss: 0.2974 - mean_squared_error: 0.2974
# Epoch 103/237
# 17/17 - 0s - loss: 0.2971 - mean_squared_error: 0.2971
# Epoch 104/237
# 17/17 - 0s - loss: 0.2975 - mean_squared_error: 0.2975
# Epoch 105/237
# 17/17 - 0s - loss: 0.2964 - mean_squared_error: 0.2964
# Epoch 106/237
# 17/17 - 0s - loss: 0.3002 - mean_squared_error: 0.3002
# Epoch 107/237
# 17/17 - 0s - loss: 0.3014 - mean_squared_error: 0.3014
# Epoch 108/237
# 17/17 - 0s - loss: 0.3048 - mean_squared_error: 0.3048
# Epoch 109/237
# 17/17 - 0s - loss: 0.2993 - mean_squared_error: 0.2993
# Epoch 110/237
# 17/17 - 0s - loss: 0.2963 - mean_squared_error: 0.2963
# Epoch 111/237
# 17/17 - 0s - loss: 0.2940 - mean_squared_error: 0.2940
# Epoch 112/237
# 17/17 - 0s - loss: 0.2936 - mean_squared_error: 0.2936
# Epoch 113/237
# 17/17 - 0s - loss: 0.2930 - mean_squared_error: 0.2930
# Epoch 114/237
# 17/17 - 0s - loss: 0.2928 - mean_squared_error: 0.2928
# Epoch 115/237
# 17/17 - 0s - loss: 0.2926 - mean_squared_error: 0.2926
# Epoch 116/237
# 17/17 - 0s - loss: 0.2922 - mean_squared_error: 0.2922
# Epoch 117/237
# 17/17 - 0s - loss: 0.2919 - mean_squared_error: 0.2919
# Epoch 152/237
# 17/17 - 0s - loss: 0.2832 - mean_squared_error: 0.2832
# Epoch 153/237
# 17/17 - 0s - loss: 0.2829 - mean_squared_error: 0.2829
# Epoch 154/237
# 17/17 - 0s - loss: 0.2828 - mean_squared_error: 0.2828
# Epoch 155/237
# 17/17 - 0s - loss: 0.2825 - mean_squared_error: 0.2825
# Epoch 156/237
# 17/17 - 0s - loss: 0.2825 - mean_squared_error: 0.2825
# Epoch 157/237
# 17/17 - 0s - loss: 0.2822 - mean_squared_error: 0.2822
# Epoch 158/237
# 17/17 - 0s - loss: 0.2823 - mean_squared_error: 0.2823
# Epoch 159/237
# 17/17 - 0s - loss: 0.2819 - mean_squared_error: 0.2819
# Epoch 160/237
# 17/17 - 0s - loss: 0.2821 - mean_squared_error: 0.2821
# Epoch 161/237
# 17/17 - 0s - loss: 0.2817 - mean_squared_error: 0.2817
# Epoch 162/237
# 17/17 - 0s - loss: 0.2821 - mean_squared_error: 0.2821
# Epoch 163/237
# 17/17 - 0s - loss: 0.2817 - mean_squared_error: 0.2817
# Epoch 164/237
# 17/17 - 0s - loss: 0.2825 - mean_squared_error: 0.2825
# Epoch 165/237
# 17/17 - 0s - loss: 0.2820 - mean_squared_error: 0.2820
# Epoch 166/237
# 17/17 - 0s - loss: 0.2825 - mean_squared_error: 0.2825
# Epoch 167/237
# 17/17 - 0s - loss: 0.2812 - mean_squared_error: 0.2812
# Epoch 168/237
# 17/17 - 0s - loss: 0.2812 - mean_squared_error: 0.2812
# Epoch 169/237
# 17/17 - 0s - loss: 0.2798 - mean_squared_error: 0.2798
# Epoch 170/237
# 17/17 - 0s - loss: 0.2798 - mean_squared_error: 0.2798
# Epoch 171/237
# 17/17 - 0s - loss: 0.2791 - mean_squared_error: 0.2791
# Epoch 172/237
# 17/17 - 0s - loss: 0.2790 - mean_squared_error: 0.2790
# Epoch 173/237
# 17/17 - 0s - loss: 0.2786 - mean_squared_error: 0.2786
# Epoch 174/237
# 17/17 - 0s - loss: 0.2785 - mean_squared_error: 0.2785
# Epoch 175/237
# 17/17 - 0s - loss: 0.2780 - mean_squared_error: 0.2780
# Epoch 176/237
# 17/17 - 0s - loss: 0.2778 - mean_squared_error: 0.2778
# Epoch 177/237
# 17/17 - 0s - loss: 0.2776 - mean_squared_error: 0.2776
# Epoch 178/237
# 17/17 - 0s - loss: 0.2775 - mean_squared_error: 0.2775
# Epoch 179/237
# 17/17 - 0s - loss: 0.2773 - mean_squared_error: 0.2773
# Epoch 180/237
# 17/17 - 0s - loss: 0.2771 - mean_squared_error: 0.2771
# Epoch 181/237
# 17/17 - 0s - loss: 0.2769 - mean_squared_error: 0.2769
# Epoch 182/237
# 17/17 - 0s - loss: 0.2767 - mean_squared_error: 0.2767
# Epoch 183/237
# 17/17 - 0s - loss: 0.2764 - mean_squared_error: 0.2764
# Epoch 184/237
# 17/17 - 0s - loss: 0.2763 - mean_squared_error: 0.2763
# Epoch 185/237
# Epoch 219/237
# 17/17 - 0s - loss: 0.2707 - mean_squared_error: 0.2707
# Epoch 220/237
# 17/17 - 0s - loss: 0.2708 - mean_squared_error: 0.2708
# Epoch 221/237
# 17/17 - 0s - loss: 0.2703 - mean_squared_error: 0.2703
# Epoch 222/237
# 17/17 - 0s - loss: 0.2703 - mean_squared_error: 0.2703
# Epoch 223/237
# 17/17 - 0s - loss: 0.2699 - mean_squared_error: 0.2699
# Epoch 224/237
# 17/17 - 0s - loss: 0.2700 - mean_squared_error: 0.2700
# Epoch 225/237
# 17/17 - 0s - loss: 0.2696 - mean_squared_error: 0.2696
# Epoch 226/237
# 17/17 - 0s - loss: 0.2696 - mean_squared_error: 0.2696
# Epoch 227/237
# 17/17 - 0s - loss: 0.2693 - mean_squared_error: 0.2693
# Epoch 228/237
# 17/17 - 0s - loss: 0.2694 - mean_squared_error: 0.2694
# Epoch 229/237
# 17/17 - 0s - loss: 0.2691 - mean_squared_error: 0.2691
# Epoch 230/237
# 17/17 - 0s - loss: 0.2691 - mean_squared_error: 0.2691
# Epoch 231/237
# 17/17 - 0s - loss: 0.2689 - mean_squared_error: 0.2689
# Epoch 232/237
# 17/17 - 0s - loss: 0.2691 - mean_squared_error: 0.2691
# Epoch 233/237
# 17/17 - 0s - loss: 0.2690 - mean_squared_error: 0.2690
# Epoch 234/237
# 17/17 - 0s - loss: 0.2693 - mean_squared_error: 0.2693
# Epoch 235/237
# 17/17 - 0s - loss: 0.2689 - mean_squared_error: 0.2689
# Epoch 236/237
# 17/17 - 0s - loss: 0.2691 - mean_squared_error: 0.2691
# Epoch 237/237
# 17/17 - 0s - loss: 0.2687 - mean_squared_error: 0.2687
# WARNING:tensorflow:From /home/qq/.virtualenvs/book/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/qq/.virtualenvs/book/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./structured_data_regressor/best_model/assets

# %% [markdown]
# ### Predict with the best model.

# %%
predicted_y = regressor.predict(test_data)
print(predicted_y)
# Out:
# [[0.5327287]
#  [1.2326038]
#  [4.6224294]
#  ...
#  [4.699002 ]
#  [0.6444111]
#  [1.9127425]]

# %% [markdown]
# ### Evaluate the best model on the test data.

# %%
test_loss, test_mse = regressor.evaluate(test_data, test_targets, verbose=0)
print('Test MSE: ', test_mse)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x7ff1083f4158> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Test MSE:  0.31036660075187683

# %% [markdown]
# ### Enable customized early stop epoch

# %%
regressor = ak.StructuredDataRegressor(max_trials=100)

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10) # control early stopping

regressor.fit(x=train_data, 
              y=train_targets, 
              epochs=200,
              batch_size=4096, 
              verbose=2, 
              callbacks=[callback])

# %% [markdown]
# ## Reference
# [ImageClassifier](/image_classifier),
# [AutoModel](/auto_model/#automodel-class),
# [ImageBlock](/block/#imageblock-class),
# [Normalization](/preprocessor/#normalization-class),
# [ImageAugmentation](/preprocessor/#image-augmentation-class),
# [ResNetBlock](/block/#resnetblock-class),
# [ImageInput](/node/#imageinput-class),
# [ClassificationHead](/head/#classificationhead-class).
